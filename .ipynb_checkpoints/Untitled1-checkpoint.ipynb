# %%
from qdevil_code import *
from saveClass import *

# %%
qd = QDevil()

# %%
qd.setGate('abda', 11)

# %%
qd.setGate('One', 1)
qd.setGate('2', 10)

# %%
qd._parseChannel('2')
# Out:
# array([10])

# %%
def save2D(result, channel1, start1, stop1, channel2, start2,stop2):
    curr_state =qd._convertDF()
    ch1 = qd._parseChannel(channel1)[0]
    ch2 = qd._parseChannel(channel2)[0]

    curr_state.loc['Channel %s' % (ch1,), 'Voltage'] = '%s to %s' % (start1, stop1) 
    curr_state.loc['Channel %s' % (ch2,), 'Voltage'] = '%s to %s' % (start2, stop2)
    result = 1
    
    return savedData(result, curr_state)

def save2D(result, channel1, start1, stop1):
    curr_state =qd._convertDF()
    ch1 = qd._parseChannel(channel1)[0]
    
    #b.loc['Channel %s' % (ch1,), 'Channel Name'] = 'Small Dot Gate'
    curr_state.loc['Channel %s' % (ch1,), 'Voltage'] = '%s to %s' % (start1, stop1) 

    result = 1
    
    return savedData(result, curr_state)

# %%
sd = savea(4, -1, 2, '2', 3, 5)

# %%
sd.state
# Out:
#            Channel Name  Voltage
# Channel 1           One        0
# Channel 2                      0
# Channel 3                      0
# Channel 4                -1 to 2
# Channel 5                      0
# Channel 6                      0
# Channel 7                      0
# Channel 8                      0
# Channel 9                      0
# Channel 10            2   3 to 5
# Channel 11         abda        0
# Channel 12                     0
# Channel 13                     0
# Channel 14                     0
# Channel 15                     0
# Channel 16                     0
# Channel 17                     0
# Channel 18                     0
# Channel 19                     0
# Channel 20                     0
# Channel 21                     0
# Channel 22                     0
# Channel 23                     0
# Channel 24                     0
# Channel 25                     0
# Channel 26                     0
# Channel 27                     0
# Channel 28                     0
# Channel 29                     0
# Channel 30                     0
# Channel 31                     0
# Channel 32                     0
# Channel 33                     0
# Channel 34                     0
# Channel 35                     0
# Channel 36                     0
# Channel 37                     0
# Channel 38                     0
# Channel 39                     0
# Channel 40                     0
# Channel 41                     0
# Channel 42                     0
# Channel 43                     0
# Channel 44                     0
# Channel 45                     0
# Channel 46                     0
# Channel 47                     0
# Channel 48                     0

# %%
qd._convertDF()
# Out:
#            Channel Name  Voltage
# Channel 1           One        0
# Channel 2                      0
# Channel 3                      0
# Channel 4                      0
# Channel 5                      0
# Channel 6                      0
# Channel 7                      0
# Channel 8                      0
# Channel 9                      0
# Channel 10            2        0
# Channel 11         abda        0
# Channel 12                     0
# Channel 13                     0
# Channel 14                     0
# Channel 15                     0
# Channel 16                     0
# Channel 17                     0
# Channel 18                     0
# Channel 19                     0
# Channel 20                     0
# Channel 21                     0
# Channel 22                     0
# Channel 23                     0
# Channel 24                     0
# Channel 25                     0
# Channel 26                     0
# Channel 27                     0
# Channel 28                     0
# Channel 29                     0
# Channel 30                     0
# Channel 31                     0
# Channel 32                     0
# Channel 33                     0
# Channel 34                     0
# Channel 35                     0
# Channel 36                     0
# Channel 37                     0
# Channel 38                     0
# Channel 39                     0
# Channel 40                     0
# Channel 41                     0
# Channel 42                     0
# Channel 43                     0
# Channel 44                     0
# Channel 45                     0
# Channel 46                     0
# Channel 47                     0
# Channel 48                     0

# %%
qd._getName(1)
# Out:
# 'One'

# %%
qd._convertChannels([2, 'abda', 5, 'One'])
# Out:
# array([ 2, 11,  5,  1])

# %%
b=[2, 'abda', 5, 'One']

# %%
type(b)
# Out:
# list

# %%
type(b) in {np.ndarray, list, tuple}
# Out:
# True

# %%
c=b[2:]

# %%
c[1:]
# Out:
# ['One']

# %%
b.loc['Channel 2', 'Channel Name'] = 'Small Dot Gate'
b.loc['Channel 2', 'Voltage'] = '-1 to 1'

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-89e6c98d9288> in <module>()
# ----> 1 b
#
# NameError: name 'b' is not defined
